# %% [markdown]
# <a href="https://colab.research.google.com/github/fcofcosta/alura/blob/imersao_dados/Francisco_Aula01_Imersao_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                               Rua             Bairro     Cidade  Metragem  \
# 4710                  Rua Manduri  Jardim Paulistano  São Paulo       455
# 3803           Rua Félix Lattuada      Vila Oratório  São Paulo       270
# 7282                  Rua Robélia   Jardim Prudência  São Paulo       632
# 5097  Rua Mário Barbosa Rodrigues         Interlagos  São Paulo       392
# 1870                          NaN      Cidade Jardim  São Paulo       700
# 5102             Rua Dona Brígida       Vila Mariana  São Paulo       265
# 7664              Rua Paragominas          São Lucas  São Paulo       145
# 2263                          NaN     Jardim Guedala  São Paulo       505
# 5060           Rua Blumenau, 105     Vila Leopoldina  São Paulo       130
# 4433                          NaN     Retiro Morumbi  São Paulo       955
#
#       Quartos  Banheiros  Vagas                                  Valor
# 4710        6          4      6                           R$ 4.500.000
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Bairro"][6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
sum((dados["Bairro"] == "Vila Mariana"))
# Out:
# 184

# %%
tem_imoveis_vila =( dados["Bairro"] == "Vila Mariana")
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
imoveis_vila_mariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()

# %% [markdown]
# Desafios:
#
# 1 - Realizar a média da metragem para cada um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %% [markdown]
# 1 - Realizar a média da metragem para cada um dos bairros (Paulo)

# %%
mean_imoveis_bairro = dados.groupby(["Bairro"])["Metragem"].mean()
mean_imoveis_bairro
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %% [markdown]
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)

# %%
dados.groupby(["Bairro"])["Quartos"].mean()
# Out:
# Bairro
# Aclimação            3.318182
# Alto da Boa Vista    4.125000
# Alto da Lapa         3.151163
# Alto da Mooca        3.300000
# Alto de Pinheiros    3.938875
#                        ...
# Vila Água Funda      2.600000
# Água Branca          3.153846
# Água Fria            2.833333
# Água Funda           3.000000
# Água Rasa            3.500000
# Name: Quartos, Length: 701, dtype: float64

# %%
dados.groupby(["Bairro"])["Quartos" , "Banheiros"].median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                    Quartos  Banheiros
# Bairro
# Aclimação              3.0        3.0
# Alto da Boa Vista      4.0        5.5
# Alto da Lapa           3.0        4.0
# Alto da Mooca          3.0        2.0
# Alto de Pinheiros      4.0        5.0
# ...                    ...        ...
# Vila Água Funda        2.0        2.0
# Água Branca            3.0        3.0
# Água Fria              3.0        4.0
# Água Funda             3.0        2.5
# Água Rasa              3.0        2.0
#
# [701 rows x 2 columns]

# %% [markdown]
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)

# %%
dados.groupby(["Bairro"])["Quartos" , "Banheiros"].median().head(20).plot.bar()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)

# %%
dados.groupby(["Bairro"], sort=False)["Metragem", "Quartos", "Banheiros"].max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                        Metragem  Quartos  Banheiros
# Bairro
# Planalto Paulista          1300        7         12
# Jardim dos Estados         1301        7         10
# Jardim Reimberg             125        4          3
# Jardim Morumbi             1763        7          8
# Mooca                       450        4          6
# ...                         ...      ...        ...
# Parque São Jorge            120        2          1
# Vila Reis                    66        2          1
# Parque das Árvores          180        4          3
# Vila São Pedro               80        2          3
# Jardim das Carmelitas       101        3          2
#
# [701 rows x 3 columns]

# %% [markdown]
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
dados.groupby(["Rua"]).count()
# Out:
#                              Bairro  Cidade  Metragem  Quartos  Banheiros  \
# Rua
# Alameda Calicut                   1       1         1        1          1
# Alameda Campinas                  1       1         1        1          1
# Alameda Canuri                    2       2         2        2          2
# Alameda Casa Branca               1       1         1        1          1
# Alameda Franca                    4       4         4        4          4
# ...                             ...     ...       ...      ...        ...
# Travessa Saveiros de Maroim       2       2         2        2          2
# Travessa Umberto Bignardi         2       2         2        2          2
# Viela Um                          4       4         4        4          4
# Viela Um, 1059                    1       1         1        1          1
# Viela Um, 289                     2       2         2        2          2
#
#                              Vagas  Valor
# Rua
# ...
